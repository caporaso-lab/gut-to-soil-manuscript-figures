# %%
import math
import statistics
import pandas as pd
import numpy as np
import altair as alt
import vl_convert as vlc

# %%
# PARSE METADATA

# NOTE: change me
md_fp = ''
md = pd.read_csv(md_fp, sep='\t', dtype={'sample-id': str})

md = md.rename({'sample-id': 'sample_id'}, axis=1)

md = md[['sample_id', 'Bucket', 'Composting Time Point', 'SampleType']]

# drop nan & week-0 rows of HEC
md = md[~(
    (md['Composting Time Point'] == 'Human Exrement Compost') &
    (md['Composting Time Point'].isna() | md['Composting Time Point'] > 0)
)]

# keep only HE and HEC observations
md = md[md['SampleType'].isin(['Human Excrement Compost', 'Human Excrement'])]

# %%
# IMPORT CULUTURING DATA

# NOTE: change me
culturing_fp = ''
culture = pd.read_csv(culturing_fp, sep='\t', skiprows=[1])
culture = culture.rename({'sample-id': 'sample_id'}, axis='columns')

culture.head()
# Out:
#   sample_id Bucket Preliminary analysis of presence  \
# 0  772b5c41      1                            (+/+)
# 1  e706dd01      1                            (+/+)
# 2  600569a7      1                            (+/+)
# 3  b9f1a9d7      1                            (+/-)
# 4  3983043e      1                            (+/+)
#
#   Results from preliminary analysis Serial Dilution 0.1 Serial Dilution 0.01  \
# 0                                 Y           (+/+/+/+)            (+/+/+/+)
# 1                                 Y           (+/+/+/+)            (+/+/+/+)
# 2                                 Y           (+/+/+/-)            (-/-/-/-)
# 3                                 Y           (-/-/-/-)            (-/-/-/-)
# 4                                 Y           (+/+/-/-)            (-/-/-/-)
#
#   Serial Dilution 0.001 Serial Dilution 0.0001    MPN/g  \
# 0             (-/-/-/-)              (-/-/-/-)  239.791
# 1             (-/-/-/-)              (-/-/-/-)  239.791
# 2             (-/-/-/-)              (-/-/-/-)   11.451
# 3             (-/-/-/-)              (-/-/-/-)        0
# 4             (-/-/-/-)              (-/-/-/-)    6.061
#
#   Lower 95% Confidence Limit (MPN/g)  Upper 95% Confidence Limit (MPN/g)  \
# 0                              63.784                            849.372
# 1                              63.784                            849.372
# 2                               1.724                             29.699
# 3                                   0                                  0
# 4                               0.386                              16.26
#
#   Lower 95% Confidence Limit (MPN/g) .1 Upper 95% Confidence Limit (MPN/g).1  \
# 0                                38.676                              964.672
# 1                                38.676                              964.672
# 2                                 2.191                               43.744
# 3                                     0                                    0
# 4                                 0.653                               26.597
#
#   Composting Time Point         SampleType        Date
# 0                     1  Compost Post-Roll  2021-10-04
# 1                     3  Compost Post-Roll  2021-10-13
# 2                     5  Compost Post-Roll  2021-10-28
# 3                     7  Compost Post-Roll  2021-11-11
# 4                     9  Compost Post-Roll  2021-11-24

# %%
# SUBSET CULTURING DATA

# description row is duplicated
culture = culture.iloc[:-1, :]

culture = culture[['sample_id', 'MPN/g']]
culture = culture.astype({'MPN/g': float})

# %%
# DROP NA CULTURING VALUES

culture = culture[culture['MPN/g'].notna()]

# %%
# MERGE CULTURING DATA, METADATA

culture_md = culture.merge(md, on='sample_id', how='inner')

culture_only = set(culture['sample_id']) - set(md['sample_id'])
print('ids in culture, not in metadata: ', culture_only)
# Out:
# ids in culture, not in metadata:  {'4fcd5839'}

# %%
# CALCULATE PER-BUCKET MOVING AVERAGES

# sort by week for moving average calculation
culture_md = culture_md.sort_values('Composting Time Point')

# averaging period
window = 4

culture_md['MPN/g Moving Average'] = (
    culture_md.groupby(['Bucket', 'SampleType'])['MPN/g']
    .transform(lambda x: x.rolling(window=window, min_periods=1).mean())
)

# %%
line = alt.Chart(culture_md).mark_line().encode(
    x=alt.X('Composting Time Point').scale(domain=(0, 52), nice=False),
    y=alt.Y('MPN/g').scale(type='linear').title('MPN/g'),
).transform_filter(
    (alt.datum['SampleType'] == 'Human Excrement Compost')
).facet(
    facet='Bucket',
    columns=5,
    title=alt.Title(
        'Culturing MPN/g, By Bucket',
        #subtitle=['moving average, period=4',]
    )
).resolve_scale(
    y='independent',
    x='independent'
)

line
# Out:
# alt.FacetChart(...)

# %%
culture_md[culture_md['Bucket'] == 16]
# Out:
#       sample_id  MPN/g  Bucket  Composting Time Point  \
# 358    c82b032c    0.0    16.0                    1.0
# 359    0975edb5    0.0    16.0                    3.0
# 360    1db63fd8    0.0    16.0                    5.0
# 361    ccca29fb    0.0    16.0                    7.0
# 362    8be7bfa3    0.0    16.0                    9.0
# 363    21f81b81    0.0    16.0                   11.0
# 364    b7caa7d8    0.0    16.0                   13.0
# 365    e1f6d0be    0.0    16.0                   15.0
# 366    f3ace39a    0.0    16.0                   17.0
# 367    88e24a0d    0.0    16.0                   19.0
# 368    05c6e0cb    0.0    16.0                   21.0
# 369    bd31ebc5    0.0    16.0                   23.0
# 370    d12bf797    0.0    16.0                   25.0
# 371    934061d9    0.0    16.0                   27.0
# 372    f6a6100a    0.0    16.0                   29.0
# 373    36ad1824    0.0    16.0                   31.0
# 374    f1425e2e    0.0    16.0                   33.0
# 375    ec7f65cf    0.0    16.0                   35.0
# 376    d32901e3    0.0    16.0                   37.0
# 377    bdf85b57    0.0    16.0                   39.0
# 378  b01a8378-A    0.0    16.0                   41.0
# 379    c0725147    0.0    16.0                   43.0
# 380    0ca1c1f8    0.0    16.0                   45.0
# 381    bb7daa8c    0.0    16.0                   47.0
# 382    a1b057e3    0.0    16.0                   49.0
# 383    2414cd23    0.0    16.0                   51.0
#
#                   SampleType  MPN/g Moving Average
# 358  Human Excrement Compost                   0.0
# 359  Human Excrement Compost                   0.0
# 360  Human Excrement Compost                   0.0
# 361  Human Excrement Compost                   0.0
# 362  Human Excrement Compost                   0.0
# 363  Human Excrement Compost                   0.0
# 364  Human Excrement Compost                   0.0
# 365  Human Excrement Compost                   0.0
# 366  Human Excrement Compost                   0.0
# 367  Human Excrement Compost                   0.0
# 368  Human Excrement Compost                   0.0
# 369  Human Excrement Compost                   0.0
# 370  Human Excrement Compost                   0.0
# 371  Human Excrement Compost                   0.0
# 372  Human Excrement Compost                   0.0
# 373  Human Excrement Compost                   0.0
# 374  Human Excrement Compost                   0.0
# 375  Human Excrement Compost                   0.0
# 376  Human Excrement Compost                   0.0
# 377  Human Excrement Compost                   0.0
# 378  Human Excrement Compost                   0.0
# 379  Human Excrement Compost                   0.0
# 380  Human Excrement Compost                   0.0
# 381  Human Excrement Compost                   0.0
# 382  Human Excrement Compost                   0.0
# 383  Human Excrement Compost                   0.0
